# %%
import pandas as pd

# %%
# https://fortune.com/fortune500/
# https://hifld-geoplatform.opendata.arcgis.com/datasets/fortune-500-corporate-headquarters/explore?location=31.489182%2C-113.147529%2C3.91&showTable=true
companies = pd.read_csv('./Fortune_500_Corporate_Headquarters.csv')

# %%
companies
# Out:
#                 X             Y  FID  OBJECTID  RANK  \
# 0   -1.293321e+07  5.403709e+06    1         1    49
# 1   -1.292942e+07  5.392879e+06    2         2   226
# 2   -8.842930e+06  4.313449e+06    3         3   290
# 3   -1.357618e+07  4.507432e+06    4         4   440
# 4   -1.357871e+07  4.508509e+06    5         5   198
# ..            ...           ...  ...       ...   ...
# 495 -9.784044e+06  5.206344e+06  496       496   111
# 496 -8.367717e+06  4.859359e+06  497       497    31
# 497 -9.407100e+06  4.736452e+06  498       498    36
# 498 -1.038271e+07  5.617628e+06  499       499   239
# 499 -1.035218e+07  5.613759e+06  500       500    94
#
#                             NAME                         ADDRESS  \
# 0                ALBERTSONS COS.        250 PARKCENTER BOULEVARD
# 1              MICRON TECHNOLOGY          8000 SOUTH FEDERAL WAY
# 2    LABORATORY CORP. OF AMERICA           358 SOUTH MAIN STREET
# ...

# %%
companies.columns
# Out:
# Index(['X', 'Y', 'FID', 'OBJECTID', 'RANK', 'NAME', 'ADDRESS', 'ADDRESS2',
#        'CITY', 'STATE', 'ZIP', 'COUNTY', 'EMPLOYEES', 'REVENUES', 'LATITUDE',
#        'LONGITUDE', 'SOURCE', 'PRC', 'COUNTYFIPS', 'COMMENTS', 'WEBSITE',
#        'PROFIT', 'GlobalID', 'CreationDate', 'Creator', 'EditDate', 'Editor'],
#       dtype='object')

# %%
companies.iloc[0]
# Out:
# X                                       -12933208.6467
# Y                                         5403708.5245
# FID                                                  1
# OBJECTID                                             1
# RANK                                                49
# NAME                                   ALBERTSONS COS.
# ADDRESS                       250 PARKCENTER BOULEVARD
# ADDRESS2                                 NOT AVAILABLE
# CITY                                             BOISE
# STATE                                               ID
# ZIP                                              83706
# COUNTY                                             ADA
# EMPLOYEES                                       274000
# REVENUES                                         58734
# LATITUDE                                      43.59974
# LONGITUDE                                   -116.18099
# SOURCE                                       BING MAPS
# ...

# %%
companies.REVENUES.value_counts()
# Out:
# 9061      3
# 6632      2
# 12394     2
# 7651      2
# 13982     1
#          ..
# 177526    1
# 7517      1
# 7515      1
# 10630     1
# 11262     1
# Name: REVENUES, Length: 495, dtype: int64

# %%
print(companies.REVENUES.min())
print(companies.REVENUES.max())
# Out:
# 5145
# 485873

# %%
# pd.Series(companies.REVENUES).plot(kind="line")
companies.REVENUES.plot(kind="line")
# Out:
# <AxesSubplot:>
